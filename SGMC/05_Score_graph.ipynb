# %% [markdown]
# # Install

# %%
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the data from the CSV files
above_90 = pd.read_csv('./data/output/sample_data_above_90.csv')
above_80 = pd.read_csv('./data/output/sample_data_above_80.csv')
above_70 = pd.read_csv('./data/output/sample_data_above_70.csv')
below_69 = pd.read_csv('./data/output/sample_data_below_69.csv')

# %%
above_90.count()
# Out:
# Unnamed: 0              12
# Acc                     12
# ID                      12
# Center Names            12
# Submitted_by            12
# Biosample_Submission    12
# Institution             12
# Country/territory       12
# Score                   12
# dtype: int64

# %%
# Compute the average accuracy score for each dataframe
avg_above_90 = above_90['Score'].mean()
avg_above_80 = above_80['Score'].mean()
avg_above_70 = above_70['Score'].mean()
avg_below_69 = below_69['Score'].mean()

# %%
# Count the number of rows in each dataframe
counts = [len(above_90), len(above_80), len(above_70), len(below_69)]
# Create a bar plot
plt.bar(['above_90', 'above_80', 'above_70', 'below_69'], counts)
# Add labels and title
plt.xlabel(' Score range')
plt.ylabel('Number of rows')
plt.title('Score  of matched rows')
# Add the average accuracy score to each bar
plt.text(-0.4, max(counts) * 1, f"Avg: {avg_above_90:.2f}")
plt.text(0.7, max(counts) * 0.55, f"Avg: {avg_above_80:.2f}")
plt.text(1.66, max(counts) * 0.95, f"Avg: {avg_above_70:.2f}")
plt.text(2.65, max(counts) * 0.1, f"Avg: {avg_below_69:.2f}")
# plt.text(2, max(counts) * 1, f"[15+5+10+1=31]")
# Display the plot
plt.show()
